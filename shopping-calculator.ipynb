# %%
user_input= input("Enter all your prices like this (e.g: 10,20,30): ")
text_prices= user_input.split(",")
total= 0
for item in text_prices:
    total+= float(item)
if total >50:
    total-= 5
    print(f"You got a $5 discount")
print(f"Total: ${total}")
# Out:
# Enter all your prices like this (e.g: 10,20,30):  20,50,60,30,50,90
# You got a $5 discount
# Total: $295.0
